# %% [markdown]
# <a href="https://colab.research.google.com/github/shuen1106lu/Program-Language/blob/main/%E3%80%8C%E7%AC%AC%E5%8D%81%E5%91%A8_%E6%96%87%E5%AD%97%E5%88%86%E9%A1%9E_%E9%80%B2%E9%9A%8E%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **關於「幻想鄉」的描述與簡介，及常見字詞的特色**

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1D072ZNIrEiR3FKym76eQ_R0ywGVsGh6EddzmnMnVV5M/edit?usp=sharing').sheet1

# %%
dicts = gc.open_by_url('https://docs.google.com/spreadsheets/d/1D072ZNIrEiR3FKym76eQ_R0ywGVsGh6EddzmnMnVV5M/edit?usp=sharing').get_worksheet(1)
dicts = dicts.get_all_records()
dicts = pd.DataFrame(dicts)

# %%
# 讀取所有數據
rows = gsheets.get_all_records()
import pandas as pd
df = pd.DataFrame(rows)

# %%
df.head()
# Out:
#   Sections                                    Cleaned_Content
# 0       前言  「幻想鄉」是日本同人遊戲系列《東方Project》（由ZUN／太田順也創作）的核心舞台，是一...
# 1  地理位置與結界  幻想鄉原本位於日本本州東北部的深山（現實中的岐阜縣白川鄉附近），但隨著外界科學文明的發展，1...
# 2     社會結構  人類與非人類共存：人類村落（主要位於「人間之里」）與妖怪、神明、妖精等超自然生物形成微妙的平...
# 3     人間之里  普通人類居住地，受慧音（半獸白澤）的歷史知識保護，避免被妖怪侵擾。村民對妖怪既恐懼又依賴（如...
# 4     妖怪之山  天狗（新聞社《文々。新聞》）、河童（科技研發）、守矢神社（外來神明風神諏訪子與八坂神奈子）的...

# %%
df.describe()
# Out:
#        Sections                                    Cleaned_Content
# count        30                                                 30
# unique       30                                                 30
# top          前言  「幻想鄉」是日本同人遊戲系列《東方Project》（由ZUN／太田順也創作）的核心舞台，是一...
# freq          1                                                  1

# %%
# !pip install jieba
# !pip install snownlp
# Out:
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (0.42.1)
# Collecting snownlp
#   Downloading snownlp-0.12.3.tar.gz (37.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 24.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: snownlp
#   Building wheel for snownlp (setup.py) ... done
#   Created wheel for snownlp: filename=snownlp-0.12.3-py3-none-any.whl size=37760946 sha256=892a94e130bab2ba2e7ed9ebd80f61d5e6b39b256cc52f7bd25315d15212d7b8
#   Stored in directory: /root/.cache/pip/wheels/4a/fc/04/d1937c02b2a445b34754da55f71612a3df648a38d711bd17eb
# Successfully built snownlp
# Installing collected packages: snownlp
# Successfully installed snownlp-0.12.3

# %%
import jieba
from snownlp import SnowNLP
import pandas as pd
from collections import Counter
import re
import plotly.express as px

# %%
for _, row in dicts.iterrows():
    word = row['words']
    jieba.add_word(word, freq=10000)
    jieba.suggest_freq(word, tune=True)
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.583 seconds.
# DEBUG:jieba:Loading model cost 0.583 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.

# %%
# 只保留中文字
def extract_chinese(text):
    return ''.join(re.findall(r'[\u4e00-\u9fa5]', text))

# %%
df['Chinese_Content'] = df['Cleaned_Content'].apply(extract_chinese)

# 使用 Jieba 斷詞
df['Tokenized'] = df['Chinese_Content'].apply(lambda x: list(jieba.cut(x, HMM=True)))

# 展平成所有詞語的列表
all_words = [word for tokens in df['Tokenized'] for word in tokens if len(word) > 1]

# %%
df['Chinese_Content']
# Out:
# 0     幻想鄉是日本同人遊戲系列東方由太田順也創作的核心舞台是一個充滿妖怪神明人類與超自然現象的封閉...
# 1     幻想鄉原本位於日本本州東北部的深山現實中的岐阜縣白川鄉附近但隨著外界科學文明的發展世紀末年被...
# 2     人類與非人類共存人類村落主要位於人間之里與妖怪神明妖精等超自然生物形成微妙的平衡妖怪需要人類...
# 3     普通人類居住地受慧音半獸白澤的歷史知識保護避免被妖怪侵擾村民對妖怪既恐懼又依賴如依賴巫女退治...
# 4     天狗新聞社文新聞河童科技研發守矢神社外來神明風神諏訪子與八坂神奈子的據點展現科技與信仰的衝突...
# 5     吸血鬼蕾米莉亞斯卡蕾特的洋館象徵西洋幻想的入侵與日式妖怪形成對比女僕長十六夜咲夜的能力操控時...
# 6                  生與死的界限模糊幽幽子亡靈管理者與映姬地獄審判體現東方對輪迴與罪罰的詮釋
# 7     幻想鄉是被遺忘之物的避難所外界失去信仰的神明如守矢雙神與瀕危妖怪在此延續隱喻傳統文化在現代社...
# 8     無絕對善惡妖怪吃人是天性人類退治妖怪是自保雙方達成動態平衡如東方儚月抄中月之民與地上生物的衝...
# 9      表面是烏托邦自由奇幻實則隱藏危險弱肉強食異變頻發通過異變劇情如東方紅魔鄉的紅霧揭露幻想鄉的脆弱性
# 10    民俗的現代重構將日本百鬼夜行轉化為彈幕遊戲賦予傳統妖怪新形象如古明地覺的讀心能力搭配科幻風格...
# 11    設定矛盾部分設定隨系列發展調整如早期妖怪需要人類恐懼後期被弱化導致邏輯漏洞文化隔閡深層的日本...
# 12    幻想鄉成為和製幻想的標誌性符號影響後續作品如艦隊的鎮守府原神的稻妻城其共存哲學與生態觀回應了...
# 13    幻想鄉的魅力在於其矛盾的統一既是避世樂園也是危險戰場既懷舊又前衛通過彈幕遊戲與碎片化敘事構建...
# 14    博麗大結界並非完全封閉而是選擇性過濾允許進入失去信仰的外界神明如守矢神社被遺忘的妖怪如付喪神...
# 15    幻想鄉的地理會因異變扭曲例如東方永夜抄中永遠亭因輝夜的永遠之力從月球隱藏到竹林深處東方神靈廟...
# 16    根據東方求聞史紀幻想鄉的時間流速與外界不同可能更快或更慢如東方儚月抄中月球的時間幾乎靜止這解...
# 17    角色對時間的態度反映其本質蓬萊人輝夜妹紅永生帶來詛咒追求瞬間的意義普通妖怪時間對他們無意義但...
# 18    幻想鄉的物理法則與外界不同例如月亮可被擊碎東方永夜抄結局語言本身具有力量如東方花映塚中花朵的...
# 19    許多低級妖怪如妖精付喪神沒有名字但他們是幻想鄉生態的基石通過東方三月精等作品強調無名者的集體...
# 20    森近霖之助的香霖堂販賣外界道具但這些物品在幻想鄉會變質相機可能拍下靈魂東方香霖堂第話漫畫書被...
# 21    幻想鄉沒有統一貨幣多以物易物如人類村落用農作物換取天狗的工藝品例外是冥界使用的冥幣東方妖妖夢...
# 22    人類農民工匠巫女博麗神社的靈夢是公務員性質妖怪掠食者如露米婭藝術家如騷靈樂團研究者如帕秋莉神...
# 23    人類孩童由寺子屋上白澤慧音開設教授歷史與常識但內容經過篩選隱藏妖怪的危險性天狗社會有完整的教...
# 24    春東方妖妖夢象徵輪迴與櫻花亡靈的執念夏東方風神錄信仰與暴風雨的狂亂秋東方永夜抄收穫與永恆的孤...
# 25    幻想鄉的地圖未涵蓋全境可能存在深淵之底東方深秘錄提及的怨靈聚集地星之世界東方虹龍洞中的星辰信...
# 26    幻想鄉允許角色追求極端理想如蕾米莉亞的任性靈夢的懶散但代價是隨時面臨異變或吞噬這種浪漫的生存...
# 27    埋設大量宗教與神話彩蛋例如地靈殿的覺與戀源自佛教阿賴耶識純狐東方紺珠傳的設定融合中國嫦娥傳說...
# 28         官方刻意不解釋的設定如八雲紫的過去外界戰爭成為同人二次創作的空間形成一設與二設共生的生態
# 29    幻想鄉既是個人的幻想結晶也是對現代社會的隱喻封閉性全球化結界如同文化保護主義的極端化傳統創新...
# Name: Chinese_Content, dtype: object

# %%
df['Tokenized']
# Out:
# 0     [幻想, 鄉, 是, 日本, 同人, 遊戲, 系列, 東方, 由, 太田, 順, 也, 創作...
# 1     [幻想, 鄉, 原本, 位, 於, 日本, 本州, 東, 北部, 的, 深山, 現實, 中,...
# 2     [人類, 與, 非人, 類, 共存, 人類, 村落, 主要, 位, 於, 人間之里, 與, ...
# 3     [普通人, 類, 居住地, 受慧音, 半獸, 白澤, 的, 歷史, 知識, 保護, 避免, ...
# 4     [天狗, 新聞, 社文新聞, 河童, 科技, 研發守, 矢, 神社, 外來, 神明, 風神,...
# 5     [吸血鬼, 蕾, 米莉亞斯卡蕾特, 的, 洋館, 象, 徵, 西洋, 幻想, 的, 入侵, ...
# 6     [生, 與, 死, 的, 界限, 模糊, 幽幽, 子亡靈, 管理者, 與, 映姬, 地獄, ...
# 7     [幻想, 鄉, 是, 被, 遺忘之物, 的, 避難, 所, 外界, 失去, 信仰, 的, 神...
# 8     [無絕, 對, 善惡, 妖怪, 吃, 人, 是, 天性, 人類, 退治, 妖怪, 是, 自保...
# 9     [表面, 是, 烏托邦, 自由, 奇幻, 實則, 隱藏, 危險弱, 肉強, 食異, 變頻, ...
# 10    [民俗, 的, 現代重, 構將, 日本, 百鬼, 夜行, 轉化, 為, 彈幕, 遊戲, 賦予...
# 11    [設定, 矛盾, 部分, 設定, 隨, 系列, 發展, 調整, 如, 早期, 妖怪, 需要,...
# 12    [幻想, 鄉成, 為, 和, 製, 幻想, 的, 標誌, 性, 符號, 影響後續, 作品, ...
# 13    [幻想, 鄉, 的, 魅力, 在, 於, 其, 矛盾, 的, 統一, 既, 是, 避世, 樂...
# 14    [博麗大, 結界, 並非, 完全, 封閉, 而是, 選擇性, 過濾, 允許, 進入, 失去,...
# 15    [幻想, 鄉, 的, 地理, 會, 因異變, 扭曲, 例如, 東方永夜, 抄, 中永遠亭, ...
# 16    [根據, 東方求, 聞史紀, 幻想, 鄉, 的, 時間, 流速, 與, 外界, 不同, 可能...
# 17    [角色, 對, 時間, 的, 態度, 反映, 其本質, 蓬萊人輝, 夜妹紅, 永生, 帶來,...
# 18    [幻想, 鄉, 的, 物理, 法則, 與, 外界, 不同, 例如, 月亮, 可, 被, 擊碎...
# 19    [許多, 低級, 妖怪, 如, 妖精, 付喪神, 沒有, 名字, 但, 他們, 是, 幻想,...
# 20    [森近霖, 之助, 的, 香霖, 堂, 販賣, 外界, 道具, 但, 這些, 物品, 在, ...
# 21    [幻想, 鄉, 沒, 有統, 一貨幣, 多, 以物, 易物, 如人類, 村落, 用農, 作物...
# 22    [人類, 農民, 工匠, 巫女, 博麗, 神社, 的, 靈夢是, 公務員, 性質, 妖怪, ...
# 23    [人類, 孩童, 由寺子, 屋上, 白澤慧音, 開設, 教授, 歷史, 與, 常識, 但, ...
# 24    [春東方, 妖, 妖夢象, 徵輪, 迴, 與, 櫻花亡靈, 的, 執念夏, 東方風, 神錄,...
# 25    [幻想, 鄉, 的, 地圖, 未涵, 蓋, 全境, 可能, 存在, 深淵之底, 東方深, 秘...
# 26    [幻想, 鄉允許, 角色, 追求, 極端, 理想, 如蕾米莉亞, 的, 任性, 靈夢, 的,...
# 27    [埋設, 大量, 宗教, 與, 神話, 彩蛋, 例如, 地靈殿, 的, 覺, 與, 戀, 源...
# 28    [官方, 刻意, 不解, 釋, 的, 設定, 如八雲紫, 的, 過去, 外界, 戰爭, 成為...
# 29    [幻想, 鄉, 既, 是, 個, 人, 的, 幻想, 結晶, 也, 是, 對, 現代, 社會...
# Name: Tokenized, dtype: object

# %%
word_counts = Counter(all_words)
word_counts
# Out:
# Counter({'幻想': 30,
#          '日本': 6,
#          '同人': 3,
#          '遊戲': 4,
#          '系列': 2,
#          '東方': 6,
#          '太田': 1,
#          '創作': 3,
#          '核心': 2,
#          '舞台': 2,
#          '一個': 4,
#          '充滿': 1,
#          '妖怪': 24,
#          '神明': 7,
#          '人類': 12,
#          '超自然': 2,
#          '現象': 3,
#          '閉異': 1,
#          '世界': 9,
#          '設定': 10,
#          '融合': 2,
#          '傳統': 5,
#          '民俗': 3,
#          '道教': 1,
#          '文化': 9,
#          '獨創': 1,
#          '元素': 2,
#          '形成': 4,
#          '懷舊': 2,
#          '創新': 2,
#          '獨特': 1,
#          '以下': 1,
#          '從多個': 1,
#          '角度': 1,
#          '詳細': 1,
#          '分析': 1,
#          '評價': 1,
#          '原本': 1,
#          '本州': 1,
#          '北部': 1,
#          '深山': 1,
#          '現實': 4,
#          '岐阜': 1,
#          '縣白川鄉': 1,
#          '附近': 1,
#          '隨著': 1,
#          '外界': 14,
#          '科學': 3,
#          '文明': 2,
#          '發展': 2,
#          '世紀': 1,
#          '末年': 1,
#          '博麗大': 2,
#          '結界': 6,
#          '離成': 1,
#          '獨立': 1,
#          '博麗': 2,
#          '巫女': 4,
#          '八雲紫': 2,
#          '境界': 4,
#          '共同': 1,
#          '維護': 1,
#          '目的': 1,
#          '保護': 5,
#          '神秘': 3,
#          '存在': 8,
#          '消滅': 1,
#          '同時': 1,
#          '防止': 2,
#          '力量': 2,
#          '外洩': 1,
#          '人極難': 1,
#          '進入': 3,
#          '鄉僅': 1,
#          '通過': 3,
#          '偶然': 2,
#          '迷路': 2,
#          '邀請': 1,
#          '如東方': 6,
#          '香霖': 4,
#          '森近霖': 2,
#          '之助': 2,
#          '非人': 1,
#          '共存': 3,
#          '村落': 3,
#          '主要': 1,
#          '人間之里': 1,
#          '妖精': 2,
#          '生物': 2,
#          '微妙': 1,
#          '平衡': 3,
#          '需要': 2,
#          '恐懼': 2,
#          '維持': 1,
#          '而人類': 1,
#          '依賴': 4,
#          '賢者': 1,
#          '無統': 1,
#          '一政權': 1,
#          '沒有': 2,
#          '中央': 1,
#          '集權': 1,
#          '勢力': 1,
#          '分布': 1,
#          '妖怪之山': 1,
#          '天狗': 5,
#          '河童': 3,
#          '掌控': 1,
#          '冥界': 2,
#          '西行': 1,
#          '幽幽': 2,
#          '管理': 1,
#          '獄則': 1,
#          '四季': 1,
#          '映姬': 2,
#          '閻魔': 1,
#          '執法': 1,
#          '符卡': 1,
#          '規則': 1,
#          '博麗靈': 1,
#          '制定': 1,
#          '戰鬥': 1,
#          '法則將': 1,
#          '暴力': 1,
#          '衝突': 3,
#          '轉化': 2,
#          '為華麗': 1,
#          '彈幕': 3,
#          '對決': 1,
#          '減少': 1,
#          '傷亡並': 1,
#          '增添': 1,
#          '娛樂性': 1,
#          '反映': 5,
#          '對遊': 1,
#          '戲性': 1,
#          '觀統': 1,
#          '考量': 1,
#          '普通人': 1,
#          '居住地': 1,
#          '受慧音': 1,
#          '半獸': 1,
#          '白澤': 1,
#          '歷史': 3,
#          '知識': 2,
#          '避免': 1,
#          '侵擾': 1,
#          '村民': 1,
#          '退治': 2,
#          '閉性': 2,
#          '科技': 7,
#          '如相機': 1,
#          '電器持': 1,
#          '保守': 1,
#          '態度': 2,
#          '新聞': 1,
#          '社文新聞': 1,
#          '研發守': 1,
#          '神社': 4,
#          '外來': 1,
#          '風神': 1,
#          '訪子': 1,
#          '八坂神': 1,
#          '奈子': 1,
#          '據點': 1,
#          '展現': 1,
#          '信仰': 7,
#          '機械': 1,
#          '技術': 1,
#          '星蓮船': 1,
#          '飛船': 1,
#          '之力': 2,
#          '並存': 3,
#          '吸血鬼': 1,
#          '米莉亞斯卡蕾特': 1,
#          '洋館': 1,
#          '西洋': 1,
#          '入侵': 1,
#          '日式': 1,
#          '女僕長': 1,
#          '十六': 1,
#          '夜咲夜': 1,
#          '能力': 3,
#          '操控': 2,
#          '時間': 5,
#          '暗示': 2,
#          '時空': 1,
#          '不穩': 1,
#          '定性': 1,
#          '界限': 2,
#          '模糊': 2,
#          '子亡靈': 1,
#          '管理者': 1,
#          '地獄': 1,
#          '審判': 1,
#          '體現': 1,
#          '罪罰': 1,
#          '詮釋': 1,
#          '遺忘之物': 1,
#          '避難': 1,
#          '失去': 2,
#          '如守': 3,
#          '雙神': 1,
#          '瀕危': 1,
#          '此延續': 1,
#          '隱喻': 1,
#          '現代': 3,
#          '社會': 4,
#          '困境': 2,
#          '例在': 1,
#          '東方求': 2,
#          '聞史紀': 2,
#          '提到': 1,
#          '進步': 1,
#          '導致': 3,
#          '消退': 1,
#          '鄉通過': 1,
#          '轉此': 1,
#          '過程': 1,
#          '無絕': 1,
#          '善惡': 1,
#          '天性': 1,
#          '自保': 1,
#          '雙方達': 1,
#          '成動態': 1,
#          '之民': 1,
#          '地上': 1,
#          '角色': 3,
#          '立場': 1,
#          '多元': 2,
#          '靈夢': 2,
#          '中立': 1,
#          '八雲紫維護': 1,
#          '魔理沙': 1,
#          '追求': 3,
#          '代表': 1,
#          '不同': 3,
#          '生存': 2,
#          '哲學': 2,
#          '表面': 1,
#          '烏托邦': 2,
#          '自由': 2,
#          '奇幻': 1,
#          '實則': 1,
#          '隱藏': 3,
#          '危險弱': 1,
#          '肉強': 1,
#          '食異': 1,
#          '變頻': 1,
#          '發通': 1,
#          '過異': 1,
#          '變劇情': 1,
#          '東方紅': 1,
#          '紅霧': 1,
#          '揭露': 1,
#          '脆弱性': 1,
#          '現代重': 1,
#          '構將': 1,
#          '百鬼': 1,
#          '夜行': 1,
#          '賦予': 1,
#          '形象': 1,
#          '如古明': 1,
#          '地覺': 1,
#          '讀心': 1,
#          '搭配': 1,
#          '科幻': 1,
#          '風格': 1,
#          '開放性': 1,
#          '刻意': 2,
#          '保留': 2,
#          '空白': 1,
#          '細節': 1,
#          '鼓勵': 1,
#          '二次': 2,
#          '使東': 1,
#          '方成': 1,
#          '矛盾': 3,
#          '部分': 1,
#          '調整': 1,
#          '早期': 1,
#          '恐懼後期': 1,
#          '弱化': 1,
#          '邏輯': 1,
#          '漏洞': 1,
#          '隔閡': 1,
#          '深層': 1,
#          '神話': 2,
#          '參考': 1,
#          '可能': 5,
#          '令非': 1,
#          '日語': 1,
#          '玩家': 2,
#          '難以': 1,
#          '完全': 2,
#          '理解': 1,
#          '鄉成': 1,
#          '標誌': 1,
#          '符號': 1,
#          '影響後續': 1,
#          '作品': 2,
#          '如艦隊': 1,
#          '鎮守府': 1,
#          '原神': 1,
#          '稻妻': 1,
#          '城其': 1,
#          '生態': 2,
#          '觀回': 1,
#          '自然': 2,
#          '關注': 1,
#          '魅力': 1,
#          '統一': 1,
#          '避世': 1,
#          '樂園': 1,
#          '危險': 1,
#          '戰場': 1,
#          '前衛': 1,
#          '碎片': 1,
#          '化敘事': 1,
#          '構建': 1,
#          '可供': 1,
#          '無限': 1,
#          '探索': 1,
#          '花筒': 1,
#          '成功': 1,
#          '不僅': 2,
#          '完整性': 1,
#          '激發': 1,
#          '本質': 1,
#          '思考': 1,
#          '時代': 2,
#          '我們': 1,
#          '如何': 1,
#          '不可': 1,
#          '之物共處': 1,
#          '並非': 1,
#          '封閉': 1,
#          '而是': 1,
#          '選擇性': 1,
#          '過濾': 1,
#          '允許': 1,
#          '遺忘': 2,
#          '如付': 1,
#          '喪神': 1,
#          '三月': 2,
#          '精中': 1,
#          '禁止': 1,
#          '流出': 2,
#          '得知': 1,
#          '例外': 2,
#          '道具': 2,
#          '物理': 3,
#          '涉及': 1,
#          '概念': 1,
#          '分割': 1,
#          '例如': 4,
#          '這解釋': 2,
#          '鄉為何': 1,
#          '能容': 1,
#          '如亡靈': 1,
#          '地理': 1,
#          '因異變': 1,
#          '扭曲': 1,
#          '東方永夜': 3,
#          '中永遠亭': 1,
#          '因輝夜': 1,
#          '永遠': 1,
#          '月球': 2,
#          '竹林': 1,
#          '深處': 1,
#          '神靈廟': 1,
#          '中神': 1,
#          '靈界': 1,
#          '現世': 1,
#          '神靈': 1,
#          '實體化': 1,
#          '這種': 4,
#          '彈性': 1,
#          '空間': 2,
#          '擴展': 1,
#          '觀而': 1,
#          '不受': 1,
#          '限制': 1,
#          '根據': 1,
#          '流速': 1,
#          '更快': 1,
#          '更慢': 1,
#          '幾乎': 1,
#          '靜止': 1,
#          '為何': 1,
#          '江戶': 1,
#          '風貌': 1,
#          '如河童': 1,
#          '電腦': 1,
#          '其本質': 1,
#          '蓬萊人輝': 1,
#          '夜妹紅': 1,
#          '永生': 1,
#          '帶來': 1,
#          '詛咒': 1,
#          '瞬間': 1,
#          '意義': 1,
#          '普通': 1,
#          '他們': 3,
#          '意義但': 1,
#          '需人類': 1,
#          '記憶維持': 1,
#          '如靈': 1,
#          '生命': 1,
#          '促使': 1,
#          '積極': 1,
#          '解決': 1,
#          '異變': 2,
#          '法則': 1,
#          '月亮': 1,
#          '擊碎': 1,
#          '結局': 1,
#          '語言': 1,
#          '本身': 2,
#          '具有': 1,
#          '如東': 1,
#          '方花映': 1,
#          '花朵': 1,
#          '花語': 1,
#          '影響': 2,
#          '暗喻': 1,
#          '只是': 1,
#          '解釋': 1,
#          '一種': 1,
#          '方式': 1,
#          '許多': 1,
#          '低級': 1,
#          '付喪神': 1,
#          '名字': 1,
#          '鄉生態': 1,
#          '基石': 1,
#          '精等': 1,
#          '強調': 1,
#          '無名者': 1,
#          '集體': 1,
#          '意識': 1,
#          '比個體': 1,
#          '強者': 1,
#          '現化': 1,
#          '販賣': 1,
#          '這些': 2,
#          '物品': 1,
#          '鄉會': 1,
#          '變質': 1,
#          '相機': 1,
#          '拍下': 1,
#          '靈魂': 1,
#          '第話': 1,
#          '漫畫': 1,
#          '當成': 1,
#          '咒術': 1,
#          '典籍': 1,
#          '移植': 1,
#          '諷刺': 1,
#          '脫離': 1,
#          '原語境': 1,
#          '藝術會': 1,
#          '成為': 3,
#          '迷信': 1,
#          '有統': 1,
#          '一貨幣': 1,
#          '以物': 1,
#          '易物': 1,
#          '如人類': 1,
#          '用農': 1,
#          '作物': 1,
#          '換取': 1,
#          '工藝品': 1,
#          '使用': 1,
#          '冥幣': 1,
#          '中小': 1,
#          '薪水': 1,
#          '活人': 1,
#          '無價值': 1,
#          '農民': 1,
#          '工匠': 1,
#          '靈夢是': 1,
#          '公務員': 1,
#          '性質': 1,
#          '食者': 1,
#          '如露': 1,
#          '米婭': 1,
#          '藝術家': 1,
#          '如騷': 1,
#          '靈樂團': 1,
#          '研究者': 1,
#          '如帕秋莉': 1,
#          '維生': 1,
#          '需主動': 1,
#          '宣傳': 1,
#          '教義': 1,
#          '孩童': 1,
#          '由寺子': 1,
#          '屋上': 1,
#          '白澤慧音': 1,
#          '開設': 1,
#          '教授': 1,
#          '常識': 1,
#          '內容': 1,
#          '經過': 1,
#          '篩選': 1,
#          '危險性': 1,
#          '完整': 1,
#          '教育': 1,
#          '體系': 1,
#          '東方文花': 1,
#          '中射命': 1,
#          '丸文': 1,
#          '提過': 1,
#          '學校': 1,
#          '春東方': 1,
#          '妖夢象': 1,
#          '徵輪': 1,
#          '櫻花亡靈': 1,
#          '執念夏': 1,
#          '東方風': 1,
#          '神錄': 1,
#          '暴風雨': 1,
#          '狂亂秋': 1,
#          '抄收': 1,
#          '永恆': 1,
#          '孤寂': 1,
#          '冬東': 1,
#          '方雪蓮空': 1,
#          '純淨': 1,
#          '死亡': 1,
#          '靜默': 1,
#          '地圖': 1,
#          '未涵': 1,
#          '全境': 1,
#          '深淵之底': 1,
#          '東方深': 1,
#          '秘錄': 1,
#          '提及': 1,
#          '怨靈': 1,
#          '聚集地': 1,
#          '東方虹': 1,
#          '龍洞': 1,
#          '星辰': 1,
#          '源頭': 1,
#          '區域': 1,
#          '擴張': 1,
#          '鄉允許': 1,
#          '極端': 1,
#          '理想': 1,
#          '如蕾米莉亞': 1,
#          '任性': 1,
#          '懶散': 1,
#          '但代價': 1,
#          '隨時': 1,
#          '面臨': 1,
#          '吞噬': 1,
#          '浪漫': 1,
#          '競爭': 1,
#          '符合': 1,
#          '青少年': 1,
#          '想像': 1,
#          '埋設': 1,
#          '大量': 1,
#          '宗教': 1,
#          '彩蛋': 1,
#          '地靈殿': 1,
#          '源自': 1,
#          '佛教': 1,
#          '阿賴': 1,
#          '耶識': 1,
#          '純狐東': 1,
#          '方紺': 1,
#          '珠傳': 1,
#          '中國': 1,
#          '嫦娥': 1,
#          '傳說': 1,
#          '蘇魯': 1,
#          '官方': 1,
#          '不解': 1,
#          '如八雲紫': 1,
#          '過去': 1,
#          '戰爭': 1,
#          '一設': 1,
#          '二設': 1,
#          '共生': 1,
#          '結晶': 1,
#          '隱喻封': 1,
#          '全球化': 1,
#          '如同': 1,
#          '主義的': 1,
#          '極端化': 1,
#          '和洋': 1,
#          '折衷': 1,
#          '記憶': 1,
#          '斷層': 1,
#          '抗爭': 1,
#          '多義性': 1,
#          '使得': 1,
#          '超越': 1,
#          '單純': 1,
#          '值得': 1,
#          '反覆': 1,
#          '解讀': 1})

# %%
# 排除停用詞
stop_words = set(['所以','極','難','好','這種','可能','維護','形成','沒有','因為','例如','大家','的','是','了','我','也','在','為','就','不','有','他','她','一個','我們','這個','如','過'])
filtered_word_counts = {word: count for word, count in word_counts.items() if word not in stop_words}

# %%
# 將詞頻轉為 DataFrame 並排序
word_freq_df = pd.DataFrame(filtered_word_counts.items(), columns=['Word', 'Frequency'])
word_freq_df = word_freq_df.sort_values(by='Frequency', ascending=False).reset_index(drop=True)

# 繪製關鍵字統計的條形圖
fig = px.bar(word_freq_df.head(30), x='Word', y='Frequency',
             title='關鍵字出現次數統計（前20名）',
             labels={'Word': '關鍵字', 'Frequency': '出現次數'},
             text='Frequency')

fig.update_layout(
    xaxis_title="關鍵字",
    yaxis_title="出現次數",
    xaxis=dict(showgrid=True),
    yaxis=dict(showgrid=True),
    template='plotly_white'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="393dee8b-ac60-493e-bd5c-19175f0e1fc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("393dee8b-ac60-493e-bd5c-19175f0e1fc1")) {                    Plotly.newPlot(                        "393dee8b-ac60-493e-bd5c-19175f0e1fc1",                        [{"alignmentgroup":"True","hovertemplate":"關鍵字=%{x}\u003cbr\u003e出現次數=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[30.0,24.0,14.0,12.0,10.0,9.0,9.0,8.0,7.0,7.0,7.0,6.0,6.0,6.0,6.0,5.0,5.0,5.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,3.0,3.0],"textposition":"auto","x":["幻想","妖怪","外界","人類","設定","文化","世界","存在","信仰","神明","科技","結界","東方","日本","如東方","時間","傳統","反映","天狗","保護","香霖","社會","依賴","現實","巫女","遊戲","境界","神社","平衡","村落"],"xaxis":"x","y":[30,24,14,12,10,9,9,8,7,7,7,6,6,6,6,5,5,5,5,5,4,4,4,4,4,4,4,4,3,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size": ...

# %%
word_freq_df
# Out:
#     Word  Frequency
# 0     幻想         30
# 1     妖怪         24
# 2     外界         14
# 3     人類         12
# 4     設定         10
# ..   ...        ...
# 591   紅霧          1
# 592  東方紅          1
# 593  變劇情          1
# 594   過異          1
# 595   搭配          1
#
# [596 rows x 2 columns]

# %%
# !apt-get update -qq
# !apt-get install -y fonts-wqy-zenhei
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-wqy-zenhei
# 0 upgraded, 1 newly installed, 0 to remove and 36 not upgraded.
# Need to get 7,472 kB of archives.
# After this operation, 16.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Fetched 7,472 kB in 2s (4,603 kB/s)
# Selecting previously unselected package fonts-wqy-zenhei.
# (Reading database ... 126333 files and directories currently installed.)
# Preparing to unpack .../fonts-wqy-zenhei_0.9.45-8_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-8) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
from google.colab import userdata
apikey = userdata.get('GOOGLE_API_KEY')

# %%
import google.generativeai as genai
genai.configure(api_key = apikey)
model = genai.GenerativeModel("gemini-1.5-flash")

prompt = f"請摘要出這些回答，依照「人」、「事」、「時」、「地」、「物」五個分類。整理出出現最多的關鍵詞：{df.to_string()}"

response = model.generate_content(prompt)
print(response.text)
# Out:
# ## 東方Project幻想鄉設定摘要
#
# 根據提供的文本，對幻想鄉的設定可以依照「人」、「事」、「時」、「地」、「物」五個分類，並整理出出現最多的關鍵詞：
#
#
# **一、人：**
#
# * **主要角色:** 博麗靈夢、八雲紫、蕾米莉亞·斯卡蕾特、十六夜咲夜、西行寺幽幽子、四季映姬、上白澤慧音、輝夜、妹紅、射命丸文、森近霖之助、帕秋莉·諾蕾姬、露米婭等。
# * **角色類型:** 人類、妖怪（天狗、河童、妖精、亡靈等）、神明、半獸人等。
# * **角色關係:**  人類與妖怪、神明等超自然生物的共存關係，不同角色間的立場和理念衝突（如靈夢的中立、八雲紫的平衡維護、魔理沙的知識追求）。
# * **關鍵詞:**  靈夢, 八雲紫, 蕾米莉亞,  妖怪,  人類,  神明,  巫女
#
#
# **二、事：**
#
# * **主要事件:**  異變（如紅霧事件）、妖怪與人類的衝突、神明的介入、結界的維護、外界文化的影響。
# * **活動:**  戰鬥（符卡規則下的彈幕對決）、交易（以物易物）、教育（寺子屋、天狗學校）、信仰活動（守矢神社）。
# * **關鍵詞:**  異變,  戰鬥,  符卡,  交易,  信仰,  結界,  文化交流
#
#
# **三、時：**
#
# * **時間線:**  19世紀末（1884年）博麗大結界建立，幻想鄉與外界隔離。
# * **時間流速:**  幻想鄉的時間流速與外界不同，可能更快或更慢，導致幻想鄉保留江戶時代的風貌，卻又存在現代科技。
# * **時間概念:**  永恆與輪迴的衝突，角色對時間的不同態度（如蓬萊人的永生詛咒、妖怪對時間的無感）。
# * **關鍵詞:**  19世紀末,  時間流速,  永恆,  輪迴,  江戶時代
#
#
# **四、地：**
#
# * **主要地點:** 幻想鄉（整體）、人間之里、妖怪之山、紅魔館、冥界、地獄、守矢神社、永遠亭、月球、深淵之底、星之世界等。
# * **地理特徵:**  深山、被結界隔離的異世界、空間具有彈性（會因異變扭曲）。
# * **關鍵詞:**  幻想鄉,  人間之里,  妖怪之山,  紅魔館,  冥界,  結界,  月球
#
#
# **五、物：**
#
# * **關鍵物品:**  博麗大結界、符卡、冥幣、外界科技產品（相機、電腦等）、農作物、工藝品、宗教或神話相關物品。
# * **環境元素:**  妖怪、神明、自然景觀（櫻花、竹林等）。
# * **關鍵詞:**  結界,  符卡,  冥幣,  科技,  農作物,  工藝品,  妖怪
#
#
# **出現最多的關鍵詞:**
#
# 幻想鄉、妖怪、人類、結界、時間、異變
#
#
# **總結:**
#
# 幻想鄉的設定是一個融合了日本傳統民俗、神道教、妖怪文化以及西方幻想元素的獨特世界。它既是一個相對封閉的、充滿奇幻與危險的異世界，也是一個反映現代社會文化矛盾與衝突的文化鏡像。  其設定的矛盾性、開放性以及對傳統文化的重新詮釋，使其成為一個值得深入探索和研究的文化現象。

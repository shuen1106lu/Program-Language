# %% [markdown]
# <a href="https://colab.research.google.com/github/shuen1106lu/Program-Language/blob/main/%E7%AC%AC%E4%BA%94%E5%91%A8%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
import pandas as pd
from gspread_dataframe import set_with_dataframe

# %%
creds, _ = default()
gc = gspread.authorize(creds)

# %%
SPREADSHEET_URL = 'https://docs.google.com/spreadsheets/d/14M0PcGeLPk-pwl6etoQYYiRo_JRy28sj6-uElhvsw2c/edit?usp=sharing'

try:
    gsheets = gc.open_by_url(SPREADSHEET_URL)
    worksheet = gsheets.get_worksheet(0)  # 選擇第一個工作表
    print(f"成功取得試算表：{gsheets.title}，工作表：{worksheet.title}")
except Exception as e:
    print("❌ 無法開啟 Google 試算表，請確認 URL 是否正確")
    print(e)
# Out:
# 成功取得試算表：第二周_自我練習，工作表：工作表1

# %%
data = worksheet.get_all_values()
if not data:
    raise ValueError("❌ 試算表為空，請確認數據是否正確")

df = pd.DataFrame(data[1:], columns=data[0])  # 第一行作為標題
print(df.head())  # 顯示前 5 行，確認數據是否正常
# Out:
#   Day                   Time            First           Second Playtimes
# 0   1                Morning  ZenlessZoneZero          Genshin        75
# 1   1              Afternoon  ZenlessZoneZero             None        45
# 2   1                  Night         Starrail  ZenlessZoneZero       105
# 3   1  Total Daily Playtimes                                         225
# 4   2                Morning          Genshin             None        30

# %%
import pandas as pd

df
# Out:
#     Day                   Time            First           Second Playtimes
# 0     1                Morning  ZenlessZoneZero          Genshin        75
# 1     1              Afternoon  ZenlessZoneZero             None        45
# 2     1                  Night         Starrail  ZenlessZoneZero       105
# 3     1  Total Daily Playtimes                                         225
# 4     2                Morning          Genshin             None        30
# ..   ..                    ...              ...              ...       ...
# 115  29  Total Daily Playtimes                                         285
# 116  30                Morning         Starrail          Genshin        90
# 117  30              Afternoon  ZenlessZoneZero          Genshin        75
# 118  30                  Night         Starrail         Starrail       120
# 119  30  Total Daily Playtimes                                         285
#
# [120 rows x 5 columns]

# %%
Day = df[df['Time'] == 'Morning']

# %%
Day
# Out:
#     Day     Time            First           Second Playtimes
# 0     1  Morning  ZenlessZoneZero          Genshin        75
# 4     2  Morning          Genshin             None        30
# 8     3  Morning  ZenlessZoneZero  ZenlessZoneZero        90
# 12    4  Morning         Starrail         Starrail       120
# 16    5  Morning  ZenlessZoneZero          Genshin        75
# 20    6  Morning             None          Genshin        30
# 24    7  Morning  ZenlessZoneZero         Starrail       105
# 28    8  Morning  ZenlessZoneZero  ZenlessZoneZero        90
# 32    9  Morning          Genshin             None        30
# 36   10  Morning          Genshin         Starrail        90
# 40   11  Morning             None  ZenlessZoneZero        45
# 44   12  Morning             None          Genshin        30
# 48   13  Morning          Genshin  ZenlessZoneZero        75
# 52   14  Morning          Genshin             None        30
# ...

# %%
items = pd.concat([Day['First'], Day['Second'],])

# %%
# Count the total playtime
time_count = items.value_counts().reset_index()

# Rename columns for clarity
time_count.columns = ['Game', 'Count']

# Sort the food items by count in descending order
time_count = time_count.sort_values(by='Count', ascending=False)

# %%
import plotly as plt
import plotly.express as px
import plotly.graph_objects as go
# Create a bar chart based on the sorted food item frequency
fig = px.bar(time_count, x='Game', y='Count', title="Gameplay Frequency (Sorted by Count)", labels={
    "Game Item": "Game Item",
    "Count": "Frequency"
})

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
